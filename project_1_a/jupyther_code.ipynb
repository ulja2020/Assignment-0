# %%
def lists(list_of_lists):
    """ 
    This function prints the elements of each list in the list and the sum of numerical values in each list
    """
    total_sum = 0

    for i in range(len(list_of_lists)):
        print(f"List {i+1} contains elements {list_of_lists[i]}")

        total = 0

        for x in list_of_lists[i]:
            if type(x) is int or type(x) is float:
                total = total + x

        print(f"The total sum in this list is {total}")

        total_sum = total_sum + total      # total sum of everything in all lists

    return total_sum

def dicts(dict_of_dicts):
    """
    Prints the elements of each dictionary in the dictionary and the sum of numerical values in each dictionary
    """
    total_sum = 0

    for i in dict_of_dicts:
        print(f"{i} contains elements {dict_of_dicts[i]}")

        total = 0

        for x in dict_of_dicts[i]:
            if type(dict_of_dicts[i][x]) is int or type(dict_of_dicts[i][x]) is float:
                total = total + dict_of_dicts[i][x]

        print(f"The total sum in this dictionary is {total}")

        total_sum = total_sum + total      # total sum of everything in all dictionaries

    return total_sum

# %%
"""defining object a list of list and printing the result from tools.py"""
my_list = [[1, "nvfkv", "mn"], [36, 2], [10, "hello", 4]]

sum_result = lists(my_list)
assert sum_result == 53            #checking that the total sum of everything in all lists is 53
print(sum_result)
# Out:
# List 1 contains elements [1, 'nvfkv', 'mn']
# The total sum in this list is 1
# List 2 contains elements [36, 2]
# The total sum in this list is 38
# List 3 contains elements [10, 'hello', 4]
# The total sum in this list is 14
# 53

# %%
"""defining object a dict of dict and printing the result from tools.py"""
my_dict = {
    "dict1": {"a": 10, "b": 3, "c": "mn"},
    "dict2": {"a": 5, "b": 2}
}
sum_result = dicts(my_dict)
assert sum_result == 20            #checking that the total sum of everything in all dictionaries is 20
print(sum_result)
# Out:
# dict1 contains elements {'a': 10, 'b': 3, 'c': 'mn'}
# The total sum in this dictionary is 13
# dict2 contains elements {'a': 5, 'b': 2}
# The total sum in this dictionary is 7
# 20
